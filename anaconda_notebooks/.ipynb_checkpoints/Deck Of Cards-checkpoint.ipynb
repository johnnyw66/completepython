# %%
from random import shuffle

class Card():
    ACEHIGH = True
    
    suits = ('Hearts', 'Clubs', 'Diamonds', 'Spades')
    rank = ('AceLo', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')

    def __init__(self, card_id):
        self.card_id = card_id
        self.value = (13 if (card_id % 13 == 0) else (card_id % 13)) if Card.ACEHIGH  else (card_id % 13) 
        self.rank = Card.rank[self.value]
        self.suit = Card.suits[int(card_id/13)]
            
    def __str__(self):
        return f"{self.rank} of {self.suit}  (value : {self.value} id : {self.card_id})"


class Pile():

    @staticmethod
    def createPileFromIds(card_id_array):
        print(card_id_array)
        pile =  Pile()
        for id in card_id_array:
            pile.add(Card(id))
        return pile

    @staticmethod
    def createPileFromCards(card_array):
        pile =  Pile()
        for card in card_array:
            pile.add(card)
        return pile
    
    def __init__(self):
        self.cards = []
    
    def deal_one_card(self):
        newDeck = self.cards[:1]
        self.cards = self.cards[1:] 
        return newDeck[0]
    
    def deal(self,size = 1):
        newDeck = self.cards[:size]
        self.cards = self.cards[size:] 
        return Pile.createPileFromCards(newDeck)
    
    def shuffle(self):
        random.shuffle(self.cards)
        
    def add(self, card):
        self.cards.append(card)

    def extend(self, other_pile):
        self.cards.extend(other_pile.cards)
        
    def peek(self,index = 0):
        return self.cards[index]
    
    def show(self):
        print(self)
        for card in self.cards:
            print(card)

    def size(self):
        return len(self.cards)
    
    def __str__(self):
        return f"Card Pile pile count {len(self.cards)}"


class Deck():
    
    def __init__(self):
        simple_full_card_deck = [i for i in range(0,52)]
        shuffle(simple_full_card_deck)
        self.pile = Pile.createPileFromIds(simple_full_card_deck)

    def deal(self, size = 1):
        dealt_pile = self.pile.deal(size)
        return dealt_pile 

    def shuffle(self):
        self.pile.shuffle()
    
    def peek(self, index = 0):
        return self.pile.peek(index)
    

    
    def show(self):
        self.pile.show()

    def size(self):
        return self.pile.size()

    def __str__(self):
        return f"{self.pile.peek(0)}"
        #return super().__str__()

class Player():
    def __init__(self, name):
        self.name = name
        self.pile = Pile()
        
    
    def add(self, pile):
        self.pile.extend(pile)

    def deal(self, number = 1):
        return self.pile.deal(number)

    def peek(self, index = 0):
        return self.pile.peek(index)
    
    def show(self):
        print(f"Player - Name:{self.name} Pile:{self.pile}")
        self.pile.show()

    def size(self):
        return self.pile.size()
    
    def __str__(self):
        return (f"Player:'{self.name}' has {self.size()} Cards")
        
if (True):
    main_card_deck = Deck() 
    player1 = Player("Player One")
    player2 = Player("Player Two")
    
#    main_card_deck.show()

    print("Dealing....") 
    player1.add(main_card_deck.deal(26))
    player2.add(main_card_deck.deal(26))
    
    game_round = 1 
    
    while True:
        if (player1.size() > 0 and player2.size() > 0):
            
            print("******* ROUND ******",game_round)
            card1 = player1.deal(1).peek()
            card2 = player2.deal(1).peek()
            winning_pile = Pile.createPileFromCards([card1,card2])
            
            print(f"{player1} showing card = {card1} card1.")
            print(f"{player2} showing card = {card2}")
            if card1.value > card2.value:
                print(f"PLAYER 1 BEATS PLAYER 2 {card1.value} beats {card2.value} i.e {card1} beats {card2}")
                player1.add(winning_pile)
                
            elif card2.value > card1.value:
                print(f'PLAYER 2 BEATS PLAYER 1 {card2} beats {card1}')
                player2.add(winning_pile)
            else:
                # War
                print("Add War")
                player1.add(winning_pile) 

            game_round +=1 
            
        else:
            break 
    
    print("**************************************GAME FINISHED**************************************")
    #print(f"Peek: {player1.peek(0)} {player1.peek(1)} {player1.peek(-1)}")
    
    player1.show() 
    player2.show() 
    

#print(a)
#print("Remaining")
#print(main_card_deck)
#print("Peek Top Card Of Main Deck",main_card_deck.peek())

#my_pile = Pile.createPileFromCards(my_cards)
#my_pile.show()
# Out:
# [31, 5, 22, 14, 39, 51, 8, 38, 0, 48, 26, 7, 40, 1, 15, 3, 20, 44, 28, 10, 34, 41, 27, 47, 16, 49, 2, 9, 25, 17, 42, 13, 32, 12, 18, 29, 21, 36, 4, 23, 46, 43, 33, 24, 19, 50, 6, 37, 45, 11, 35, 30]
# Dealing....
# ******* ROUND ****** 1
# Player:'Player One' has 25 Cards showing card = Six of Diamonds  (value : 5 id : 31) card1.
# Player:'Player Two' has 25 Cards showing card = Three of Hearts  (value : 2 id : 2)
# PLAYER 1 BEATS PLAYER 2 5 beats 2 i.e Six of Diamonds  (value : 5 id : 31) beats Three of Hearts  (value : 2 id : 2)
# ******* ROUND ****** 2
# Player:'Player One' has 26 Cards showing card = Six of Hearts  (value : 5 id : 5) card1.
# Player:'Player Two' has 24 Cards showing card = Ten of Hearts  (value : 9 id : 9)
# PLAYER 2 BEATS PLAYER 1 Ten of Hearts  (value : 9 id : 9) beats Six of Hearts  (value : 5 id : 5)
# ******* ROUND ****** 3
# Player:'Player One' has 27 Cards showing card = Ten of Clubs  (value : 9 id : 22) card1.
# Player:'Player Two' has 23 Cards showing card = King of Clubs  (value : 12 id : 25)
# PLAYER 2 BEATS PLAYER 1 King of Clubs  (value : 12 id : 25) beats Ten of Clubs  (value : 9 id : 22)
# ******* ROUND ****** 4
# Player:'Player One' has 28 Cards showing card = Two of Clubs  (value : 1 id : 14) card1.
# Player:'Player Two' has 22 Cards showing card = Five of Clubs  (value : 4 id : 17)
# PLAYER 2 BEATS PLAYER 1 Five of Clubs  (value : 4 id : 17) beats Two of Clubs  (value : 1 id : 14)
# ******* ROUND ****** 5
# Player:'Player One' has 29 Cards showing card = Ace of Spades  (value : 13 id : 39) card1.
# Player:'Player Two' has 21 Cards showing card = Four of Spades  (value : 3 id : 42)
# PLAYER 1 BEATS PLAYER 2 13 beats 3 i.e Ace of Spades  (value : 13 id : 39) beats Four of Spades  (value : 3 id : 42)
# ******* ROUND ****** 6
# Player:'Player One' has 30 Cards showing card = King of Spades  (value : 12 id : 51) card1.
# Player:'Player Two' has 20 Cards showing card = Ace of Clubs  (value : 13 id : 13)
# PLAYER 2 BEATS PLAYER 1 Ace of Clubs  (value : 13 id : 13) beats King of Spades  (value : 12 id : 51)
# ******* ROUND ****** 7
# Player:'Player One' has 31 Cards showing card = Nine of Hearts  (value : 8 id : 8) card1.
# Player:'Player Two' has 19 Cards showing card = Seven of Diamonds  (value : 6 id : 32)
# PLAYER 1 BEATS PLAYER 2 8 beats 6 i.e Nine of Hearts  (value : 8 id : 8) beats Seven of Diamonds  (value : 6 id : 32)
# ******* ROUND ****** 8
# Player:'Player One' has 32 Cards showing card = King of Diamonds  (value : 12 id : 38) card1.
# Player:'Player Two' has 18 Cards showing card = King of Hearts  (value : 12 id : 12)
# Add War
# ******* ROUND ****** 9
# Player:'Player One' has 33 Cards showing card = Ace of Hearts  (value : 13 id : 0) card1.
# Player:'Player Two' has 17 Cards showing card = Six of Clubs  (value : 5 id : 18)
# PLAYER 1 BEATS PLAYER 2 13 beats 5 i.e Ace of Hearts  (value : 13 id : 0) beats Six of Clubs  (value : 5 id : 18)
# ******* ROUND ****** 10
# Player:'Player One' has 34 Cards showing card = Ten of Spades  (value : 9 id : 48) card1.
# Player:'Player Two' has 16 Cards showing card = Four of Diamonds  (value : 3 id : 29)
# PLAYER 1 BEATS PLAYER 2 9 beats 3 i.e Ten of Spades  (value : 9 id : 48) beats Four of Diamonds  (value : 3 id : 29)
# ******* ROUND ****** 11
# Player:'Player One' has 35 Cards showing card = Ace of Diamonds  (value : 13 id : 26) card1.
# Player:'Player Two' has 15 Cards showing card = Nine of Clubs  (value : 8 id : 21)
# PLAYER 1 BEATS PLAYER 2 13 beats 8 i.e Ace of Diamonds  (value : 13 id : 26) beats Nine of Clubs  (value : 8 id : 21)
# ******* ROUND ****** 12
# Player:'Player One' has 36 Cards showing card = Eight of Hearts  (value : 7 id : 7) card1.
# Player:'Player Two' has 14 Cards showing card = Jack of Diamonds  (value : 10 id : 36)
# PLAYER 2 BEATS PLAYER 1 Jack of Diamonds  (value : 10 id : 36) beats Eight of Hearts  (value : 7 id : 7)
# ******* ROUND ****** 13
# Player:'Player One' has 37 Cards showing card = Two of Spades  (value : 1 id : 40) card1.
# Player:'Player Two' has 13 Cards showing card = Five of Hearts  (value : 4 id : 4)
# PLAYER 2 BEATS PLAYER 1 Five of Hearts  (value : 4 id : 4) beats Two of Spades  (value : 1 id : 40)
# ******* ROUND ****** 14
# Player:'Player One' has 38 Cards showing card = Two of Hearts  (value : 1 id : 1) card1.
# Player:'Player Two' has 12 Cards showing card = Jack of Clubs  (value : 10 id : 23)
# PLAYER 2 BEATS PLAYER 1 Jack of Clubs  (value : 10 id : 23) beats Two of Hearts  (value : 1 id : 1)
# ******* ROUND ****** 15
# Player:'Player One' has 39 Cards showing card = Three of Clubs  (value : 2 id : 15) card1.
# Player:'Player Two' has 11 Cards showing card = Eight of Spades  (value : 7 id : 46)
# PLAYER 2 BEATS PLAYER 1 Eight of Spades  (value : 7 id : 46) beats Three of Clubs  (value : 2 id : 15)
# ******* ROUND ****** 16
# Player:'Player One' has 40 Cards showing card = Four of Hearts  (value : 3 id : 3) card1.
# Player:'Player Two' has 10 Cards showing card = Five of Spades  (value : 4 id : 43)
# PLAYER 2 BEATS PLAYER 1 Five of Spades  (value : 4 id : 43) beats Four of Hearts  (value : 3 id : 3)
# ******* ROUND ****** 17
# Player:'Player One' has 41 Cards showing card = Eight of Clubs  (value : 7 id : 20) card1.
# Player:'Player Two' has 9 Cards showing card = Eight of Diamonds  (value : 7 id : 33)
# Add War
# ******* ROUND ****** 18
# Player:'Player One' has 42 Cards showing card = Six of Spades  (value : 5 id : 44) card1.
# Player:'Player Two' has 8 Cards showing card = Queen of Clubs  (value : 11 id : 24)
# PLAYER 2 BEATS PLAYER 1 Queen of Clubs  (value : 11 id : 24) beats Six of Spades  (value : 5 id : 44)
# ******* ROUND ****** 19
# Player:'Player One' has 43 Cards showing card = Three of Diamonds  (value : 2 id : 28) card1.
# Player:'Player Two' has 7 Cards showing card = Seven of Clubs  (value : 6 id : 19)
# PLAYER 2 BEATS PLAYER 1 Seven of Clubs  (value : 6 id : 19) beats Three of Diamonds  (value : 2 id : 28)
# ******* ROUND ****** 20
# Player:'Player One' has 44 Cards showing card = Jack of Hearts  (value : 10 id : 10) card1.
# Player:'Player Two' has 6 Cards showing card = Queen of Spades  (value : 11 id : 50)
# PLAYER 2 BEATS PLAYER 1 Queen of Spades  (value : 11 id : 50) beats Jack of Hearts  (value : 10 id : 10)
# ******* ROUND ****** 21
# Player:'Player One' has 45 Cards showing card = Nine of Diamonds  (value : 8 id : 34) card1.
# Player:'Player Two' has 5 Cards showing card = Seven of Hearts  (value : 6 id : 6)
# PLAYER 1 BEATS PLAYER 2 8 beats 6 i.e Nine of Diamonds  (value : 8 id : 34) beats Seven of Hearts  (value : 6 id : 6)
# ******* ROUND ****** 22
# Player:'Player One' has 46 Cards showing card = Three of Spades  (value : 2 id : 41) card1.
# Player:'Player Two' has 4 Cards showing card = Queen of Diamonds  (value : 11 id : 37)
# PLAYER 2 BEATS PLAYER 1 Queen of Diamonds  (value : 11 id : 37) beats Three of Spades  (value : 2 id : 41)
# ******* ROUND ****** 23
# Player:'Player One' has 47 Cards showing card = Two of Diamonds  (value : 1 id : 27) card1.
# Player:'Player Two' has 3 Cards showing card = Seven of Spades  (value : 6 id : 45)
# PLAYER 2 BEATS PLAYER 1 Seven of Spades  (value : 6 id : 45) beats Two of Diamonds  (value : 1 id : 27)
# ******* ROUND ****** 24
# Player:'Player One' has 48 Cards showing card = Nine of Spades  (value : 8 id : 47) card1.
# Player:'Player Two' has 2 Cards showing card = Queen of Hearts  (value : 11 id : 11)
# PLAYER 2 BEATS PLAYER 1 Queen of Hearts  (value : 11 id : 11) beats Nine of Spades  (value : 8 id : 47)
# ******* ROUND ****** 25
# Player:'Player One' has 49 Cards showing card = Four of Clubs  (value : 3 id : 16) card1.
# Player:'Player Two' has 1 Cards showing card = Ten of Diamonds  (value : 9 id : 35)
# PLAYER 2 BEATS PLAYER 1 Ten of Diamonds  (value : 9 id : 35) beats Four of Clubs  (value : 3 id : 16)
# ******* ROUND ****** 26
# Player:'Player One' has 50 Cards showing card = Jack of Spades  (value : 10 id : 49) card1.
# Player:'Player Two' has 0 Cards showing card = Five of Diamonds  (value : 4 id : 30)
# PLAYER 1 BEATS PLAYER 2 10 beats 4 i.e Jack of Spades  (value : 10 id : 49) beats Five of Diamonds  (value : 4 id : 30)
# **************************************GAME FINISHED**************************************
# Player - Name:Player One Pile:Card Pile pile count 52
# Card Pile pile count 52
# Six of Diamonds  (value : 5 id : 31)
# Three of Hearts  (value : 2 id : 2)
# Six of Hearts  (value : 5 id : 5)
# Ten of Hearts  (value : 9 id : 9)
# Ten of Clubs  (value : 9 id : 22)
# King of Clubs  (value : 12 id : 25)
# Two of Clubs  (value : 1 id : 14)
# Five of Clubs  (value : 4 id : 17)
# Ace of Spades  (value : 13 id : 39)
# Four of Spades  (value : 3 id : 42)
# King of Spades  (value : 12 id : 51)
# Ace of Clubs  (value : 13 id : 13)
# Nine of Hearts  (value : 8 id : 8)
# Seven of Diamonds  (value : 6 id : 32)
# King of Diamonds  (value : 12 id : 38)
# King of Hearts  (value : 12 id : 12)
# Ace of Hearts  (value : 13 id : 0)
# Six of Clubs  (value : 5 id : 18)
# Ten of Spades  (value : 9 id : 48)
# Four of Diamonds  (value : 3 id : 29)
# Ace of Diamonds  (value : 13 id : 26)
# Nine of Clubs  (value : 8 id : 21)
# Eight of Hearts  (value : 7 id : 7)
# Jack of Diamonds  (value : 10 id : 36)
# Two of Spades  (value : 1 id : 40)
# Five of Hearts  (value : 4 id : 4)
# Two of Hearts  (value : 1 id : 1)
# Jack of Clubs  (value : 10 id : 23)
# Three of Clubs  (value : 2 id : 15)
# Eight of Spades  (value : 7 id : 46)
# Four of Hearts  (value : 3 id : 3)
# Five of Spades  (value : 4 id : 43)
# Eight of Clubs  (value : 7 id : 20)
# Eight of Diamonds  (value : 7 id : 33)
# Six of Spades  (value : 5 id : 44)
# Queen of Clubs  (value : 11 id : 24)
# Three of Diamonds  (value : 2 id : 28)
# Seven of Clubs  (value : 6 id : 19)
# Jack of Hearts  (value : 10 id : 10)
# Queen of Spades  (value : 11 id : 50)
# Nine of Diamonds  (value : 8 id : 34)
# Seven of Hearts  (value : 6 id : 6)
# Three of Spades  (value : 2 id : 41)
# Queen of Diamonds  (value : 11 id : 37)
# Two of Diamonds  (value : 1 id : 27)
# Seven of Spades  (value : 6 id : 45)
# Nine of Spades  (value : 8 id : 47)
# Queen of Hearts  (value : 11 id : 11)
# Four of Clubs  (value : 3 id : 16)
# Ten of Diamonds  (value : 9 id : 35)
# Jack of Spades  (value : 10 id : 49)
# Five of Diamonds  (value : 4 id : 30)
# Player - Name:Player Two Pile:Card Pile pile count 0
# Card Pile pile count 0
